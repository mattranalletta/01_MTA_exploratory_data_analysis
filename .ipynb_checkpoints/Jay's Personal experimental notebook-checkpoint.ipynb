# %%
import pandas as pd

mta = pd.read_csv('mta_clean.zip', parse_dates=['date', 'timestamp'], low_memory=False)

# %%
mta.groupby(['ca','unit','station']).sum().sort_values(by='total',ascending=False).head(10)
# Out:
#                               entries      exits      total
# ca    unit station
# PTH22 R540 PATH NEW WTC     3125808.0  2823868.0  5949676.0
# R238  R046 GRD CNTRL-42 ST  1898925.0  3115860.0  5014785.0
# R533  R055 FLUSHING-MAIN    2611178.0  2321511.0  4932689.0
# R138  R293 34 ST-PENN STA   2373783.0  1894022.0  4267805.0
# N324  R018 JKSN HT-ROOSVLT  2314234.0  1729201.0  4043435.0
# R221  R170 14 ST-UNION SQ   1873190.0  1930149.0  3803339.0
# N506  R022 34 ST-HERALD SQ  1769489.0  1853290.0  3622779.0
# PTH03 R552 JOURNAL SQUARE   1716171.0  1767265.0  3483436.0
# R240  R047 GRD CNTRL-42 ST  1591622.0  1868745.0  3460367.0
# N051  R084 59 ST COLUMBUS   2197822.0  1242870.0  3440692.0

# %%
mta[mta['ca'] == 'R533']
# Out:
#                station                         turnstile    ca  unit  \
# 1211803  FLUSHING-MAIN  FLUSHING-MAIN-R533-R055-00-00-00  R533  R055
# 1211804  FLUSHING-MAIN  FLUSHING-MAIN-R533-R055-00-00-00  R533  R055
# 1211805  FLUSHING-MAIN  FLUSHING-MAIN-R533-R055-00-00-00  R533  R055
# 1211806  FLUSHING-MAIN  FLUSHING-MAIN-R533-R055-00-00-00  R533  R055
# 1211807  FLUSHING-MAIN  FLUSHING-MAIN-R533-R055-00-00-00  R533  R055
# ...                ...                               ...   ...   ...
# 1218598  FLUSHING-MAIN  FLUSHING-MAIN-R533-R055-00-03-07  R533  R055
# 1218599  FLUSHING-MAIN  FLUSHING-MAIN-R533-R055-00-03-07  R533  R055
# 1218600  FLUSHING-MAIN  FLUSHING-MAIN-R533-R055-00-03-07  R533  R055
# 1218601  FLUSHING-MAIN  FLUSHING-MAIN-R533-R055-00-03-07  R533  R055
# 1218602  FLUSHING-MAIN  FLUSHING-MAIN-R533-R055-00-03-07  R533  R055
#
#               scp linename division       date      time     desc  \
# 1211803  00-00-00        7      IRT 2019-07-13  04:00:00  REGULAR
# ...
